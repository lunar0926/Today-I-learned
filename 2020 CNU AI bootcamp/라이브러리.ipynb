# %%
import pandas as pd

# %%
s1 = pd.Series([10, 20, 30, 40])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1.mean()
# Out:
# 25.0

# %%
s1.sum()
# Out:
# 100

# %%
s1.max()
# Out:
# 40

# %%
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# ## 데이터 프레임
# * 정형데이터
# * index - values - column

# %%
table1 = pd.DataFrame([['2020-08-03','축산물', 12000],
               ['2020-08-04','과일', 8000],
               ['2020-08-05','수산물', 16000]],
             columns = ['날짜', '품목', '가격'])

# %%
type(table1)
# Out:
# pandas.core.frame.DataFrame

# %%
table1['날짜']
# Out:
# 0    2020-08-03
# 1    2020-08-04
# 2    2020-08-05
# Name: 날짜, dtype: object

# %%
table1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      3 non-null      object
#  1   품목      3 non-null      object
#  2   가격      3 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
table2 = pd.DataFrame({'이름':['홍길동','성춘향','변사또','이몽룡'],
              '나이':[34,25,12,60],
              '성별':['여성','여성','남성','남성'],
              '계급':['양반','왕','평민','평민']})

# %%
table2.to_excel('result1.xlsx') # 엑셀파일로 데이터프레임을 받을 수 있음.
